# %%
import pandas as pd

# %%
data=pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import seaborn as sns
sns.pairplot(data,hue='Outcome')

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
figure, axis = plt.subplots(2, 4, figsize = (30,10))
sns.boxplot(x='Outcome',y='Pregnancies',data=data,ax=axis[0,0])
sns.boxplot(x='Outcome',y='Glucose',data=data,ax=axis[0,1])
sns.boxplot(x='Outcome',y='BloodPressure',data=data,ax=axis[0,2])
sns.boxplot(x='Outcome',y='SkinThickness',data=data,ax=axis[0,3])
sns.boxplot(x='Outcome',y='Insulin',data=data,ax=axis[1,0])
sns.boxplot(x='Outcome',y='BMI',data=data,ax=axis[1,1])
sns.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=data,ax=axis[1,2])
sns.boxplot(x='Outcome',y='Age',data=data,ax=axis[1,3])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %%
outcome_zero=data[data['Outcome'] == 0]
outcome_zero
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
outcome_one=data[data['Outcome'] == 1]
outcome_one
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
def Outdet(data):
    Q1=data.quantile(0.25)
    Q3=data.quantile(0.75)
    IQR=Q3-Q1
    LR=Q1-(IQR*1.5)
    UR=Q3+(IQR*1.5)
    return Q1,Q3,IQR,LR,UR

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.Pregnancies)
print(Q1,Q3,IQR,LR,UR)
# Out:
# 1.0 5.0 4.0 -5.0 11.0

# %%
outcome_zero=outcome_zero[(outcome_zero['Pregnancies'] > LR)  &  (outcome_zero['Pregnancies'] < UR)]
outcome_zero
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.Glucose)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['Glucose'] > LR)  &  (outcome_zero['Glucose'] < UR)]
outcome_zero
# Out:
# 93.0 125.0 32.0 45.0 173.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.BloodPressure)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['BloodPressure'] > LR)  &  (outcome_zero['BloodPressure'] < UR)]
outcome_zero
# Out:
# 62.0 78.0 16.0 38.0 102.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 12            10      139             80              0        0  27.1
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.Insulin)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['Insulin'] > LR)  &  (outcome_zero['Insulin'] < UR)]
outcome_zero
# Out:
# 0.0 107.5 107.5 -161.25 268.75
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 12            10      139             80              0        0  27.1
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.BMI)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['BMI'] > LR)  &  (outcome_zero['BMI'] < UR)]
outcome_zero
# Out:
# 25.575000000000003 34.824999999999996 9.249999999999993 11.700000000000014 48.69999999999999
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 12            10      139             80              0        0  27.1
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.SkinThickness)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['SkinThickness'] > LR)  &  (outcome_zero['SkinThickness'] < UR)]
outcome_zero
# Out:
# 0.0 31.0 31.0 -46.5 77.5
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 12            10      139             80              0        0  27.1
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.DiabetesPedigreeFunction)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['DiabetesPedigreeFunction'] > LR)  &  (outcome_zero['DiabetesPedigreeFunction'] < UR)]
outcome_zero
# Out:
# 0.2325 0.5575000000000001 0.32500000000000007 -0.2550000000000001 1.0450000000000002
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.Age)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['Age'] > LR)  &  (outcome_zero['Age'] < UR)]
outcome_zero
# Out:
# 23.0 35.0 12.0 5.0 53.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.Glucose)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['Glucose'] > LR)  &  (outcome_one['Glucose'] < UR)]
outcome_one
# Out:
# 119.0 167.0 48.0 47.0 239.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.BloodPressure)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['BloodPressure'] > LR)  &  (outcome_one['BloodPressure'] < UR)]
outcome_one
# Out:
# 66.0 82.0 16.0 42.0 106.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.SkinThickness)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['SkinThickness'] > LR)  &  (outcome_one['SkinThickness'] < UR)]
outcome_one
# Out:
# 0.0 36.0 36.0 -54.0 90.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.Insulin)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['Insulin'] > LR)  &  (outcome_one['Insulin'] < UR)]
outcome_one
# Out:
# 0.0 175.0 175.0 -262.5 437.5
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.BMI)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['BMI'] > LR)  &  (outcome_one['BMI'] < UR)]
outcome_one
# Out:
# 30.9 37.975 7.075000000000003 20.287499999999994 48.587500000000006
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 11            10      168             74              0        0  38.0
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.DiabetesPedigreeFunction)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['DiabetesPedigreeFunction'] > LR)  &  (outcome_one['DiabetesPedigreeFunction'] < UR)]
outcome_one
# Out:
# 0.2705 0.73925 0.46874999999999994 -0.43262499999999987 1.4423749999999997
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 11            10      168             74              0        0  38.0
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_one.Age)
print(Q1,Q3,IQR,LR,UR)
outcome_one=outcome_one[(outcome_one['Age'] > LR)  &  (outcome_one['Age'] < UR)]
outcome_one
# Out:
# 29.0 45.0 16.0 5.0 69.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 11            10      168             74              0        0  38.0
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df=pd.concat([outcome_zero,outcome_one],axis=0)
new_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
new_df.Outcome.value_counts()
# Out:
# 0    378
# 1    220
# Name: Outcome, dtype: int64

# %%
import matplotlib.pyplot as plt
figure, axis = plt.subplots(2, 4, figsize = (30,10))
sns.boxplot(x='Outcome',y='Pregnancies',data=new_df,ax=axis[0,0])
sns.boxplot(x='Outcome',y='Glucose',data=new_df,ax=axis[0,1])
sns.boxplot(x='Outcome',y='BloodPressure',data=new_df,ax=axis[0,2])
sns.boxplot(x='Outcome',y='SkinThickness',data=new_df,ax=axis[0,3])
sns.boxplot(x='Outcome',y='Insulin',data=new_df,ax=axis[1,0])
sns.boxplot(x='Outcome',y='BMI',data=new_df,ax=axis[1,1])
sns.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=new_df,ax=axis[1,2])
sns.boxplot(x='Outcome',y='Age',data=new_df,ax=axis[1,3])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.Age)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['Age'] > LR)  &  (outcome_zero['Age'] < UR)]
outcome_zero
# Out:
# 22.0 31.0 9.0 8.5 44.5
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 760            2       88             58             26       16  28.4
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.Pregnancies)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['Pregnancies'] > LR)  &  (outcome_zero['Pregnancies'] < UR)]
outcome_zero
# Out:
# 1.0 4.0 3.0 -3.5 8.5
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.DiabetesPedigreeFunction)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['DiabetesPedigreeFunction'] > LR)  &  (outcome_zero['DiabetesPedigreeFunction'] < UR)]
outcome_zero
# Out:
# 0.2355 0.527 0.29150000000000004 -0.20175000000000004 0.96425
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
Q1,Q3,IQR,LR,UR=Outdet(outcome_zero.BloodPressure)
print(Q1,Q3,IQR,LR,UR)
outcome_zero=outcome_zero[(outcome_zero['BloodPressure'] > LR)  &  (outcome_zero['BloodPressure'] < UR)]
outcome_zero
# Out:
# 62.0 76.0 14.0 41.0 97.0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
new_df_1=pd.concat([outcome_zero,outcome_one],axis=0)
new_df_1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
import matplotlib.pyplot as plt
figure, axis = plt.subplots(2, 4, figsize = (30,10))
sns.boxplot(x='Outcome',y='Pregnancies',data=new_df_1,ax=axis[0,0])
sns.boxplot(x='Outcome',y='Glucose',data=new_df_1,ax=axis[0,1])
sns.boxplot(x='Outcome',y='BloodPressure',data=new_df_1,ax=axis[0,2])
sns.boxplot(x='Outcome',y='SkinThickness',data=new_df_1,ax=axis[0,3])
sns.boxplot(x='Outcome',y='Insulin',data=new_df_1,ax=axis[1,0])
sns.boxplot(x='Outcome',y='BMI',data=new_df_1,ax=axis[1,1])
sns.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=new_df_1,ax=axis[1,2])
sns.boxplot(x='Outcome',y='Age',data=new_df_1,ax=axis[1,3])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %%
sns.pairplot(new_df_1,hue='Outcome')

# %%
new_df_1.Outcome.value_counts()
# Out:
# 0    343
# 1    220
# Name: Outcome, dtype: int64

# %%
sns.countplot(new_df_1.Outcome)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
x=new_df_1.drop('Outcome',axis=1)
y=new_df_1['Outcome']

# %%
from sklearn.preprocessing import StandardScaler
model=StandardScaler()
model.fit_transform(x)
# Out:
# array([[-0.81450455, -1.18131175, -0.49905404, ..., -0.87629388,
#         -0.37178879,  0.0100552 ],
#        [-0.81450455, -1.04596125, -0.49905404, ..., -0.63613351,
#         -1.05221816, -1.03829286],
#        [ 0.48179527, -0.13234538,  0.2286052 , ..., -1.0364008 ,
#         -0.92648664, -0.0947796 ],
#        ...,
#        [ 0.80587022,  2.37163886,  1.86583848, ...,  0.54865768,
#         -0.64174174,  3.67927342],
#        [ 1.77809508,  1.69488636,  0.2286052 , ...,  1.90956648,
#         -0.17949353,  1.26807288],
#        [-0.81450455,  0.20603087, -1.04479846, ..., -0.31591967,
#         -0.37918476,  1.6874121 ]])

# %%
from sklearn.model_selection import train_test_split
(X_train,X_test,y_train,y_test)=train_test_split(x,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (450, 8)

# %%
X_test.shape
# Out:
# (113, 8)

# %%
from sklearn.linear_model import LogisticRegression
model_reg=LogisticRegression()

# %%
model_reg.fit(X_train,y_train)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_reg.score(X_test,y_test)
# Out:
# 0.8230088495575221

# %%
y_pred=model_reg.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87        73
#            1       0.78      0.70      0.74        40
#
#     accuracy                           0.82       113
#    macro avg       0.81      0.80      0.80       113
# weighted avg       0.82      0.82      0.82       113
